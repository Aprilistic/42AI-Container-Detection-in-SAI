# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/'
# Out:
# /content/drive/MyDrive/content/pytorch-rotation-decoupled-detector

# %%
! python run/dota/prepare.py
# Out:
# /content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/run/dota/prepare.py:33: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bbox = cv.boxPoints(cv.minAreaRect(coord)).astype(np.int).tolist()
# crop: /content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/images/train/OBJ04144_PS3_K3A_NIA0178.png /content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/annotations/train/OBJ04144_PS3_K3A_NIA0178.json
# ...

# %%
cd '/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector' # install
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector # install'
# /content/drive/MyDrive/content/pytorch-rotation-decoupled-detector

# %%
! pip install -r requirement.txt

# %%
! python run/dota/train.py
# Out:
# 2023-07-23 04:06:23.469919: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-23 04:06:24.355781: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2200 25000
# <2641/25000>: 100% 441/441 [09:50<00:00,  1.34s/it, loss_cls=8.35, loss_loc=6.37]
# <3082/25000>: 100% 441/441 [09:29<00:00,  1.29s/it, loss_cls=9.18, loss_loc=5.9]
# ...

# %%
! python run/dota/evaluate.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/run/dota/evaluate.py", line 146, in <module>
#     main()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/run/dota/evaluate.py", line 40, in main
#     current_step = max(indexes)
# ValueError: max() arg is an empty sequence

# %%
! python run/dota/visualize_label.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/content/pytorch-rotation-decoupled-detector/run/dota/visualize_label.py", line 38, in <module>
#     with open(label_path, 'r') as file:
# TypeError: expected str, bytes or os.PathLike object, not NoneType
